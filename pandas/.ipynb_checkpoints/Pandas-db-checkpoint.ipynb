# %%
import mysql.connector as connection
import pandas as pd
import warnings

warnings.filterwarnings('ignore')

try:
    mydb = connection.connect(host="db4free.net", database = 'dbtraining',user="dbuseracc1", passwd="Pa55w0rd",use_pure=True)
    query = "Select * from customers;"
    result_dataFrame = pd.read_sql(query,mydb)
    mydb.close() #close the connection
except Exception as e:
    mydb.close()
    print(str(e))

# %%
result_dataFrame
# Out:
#    customerNumber                 customerName contactLastName  \
# 0             148      Dragon Souveniers, Ltd.       Natividad
# 1             177         Osaka Souveniers Co.         Kentary
# 2             211  King Kong Collectables, Co.             Gao
# 3             385              Cruz & Sons Co.            Cruz
# 4             398      Tokyo Collectables, Ltd       Shimamura
#
#   contactFirstName             phone         addressLine1  \
# 0             Eric      +65 221 7555           Bronz Sok.
# 1             Mory  +81 06 6342 5555        1-6-20 Dojima
# 2             Mike    +852 2251 1555  Bank of China Tower
# 3           Arnold    +63 2 555 3587   15 McCallum Street
# 4            Akiko   +81 3 3584 0555       2-2-8 Roppongi
#
#                addressLine2               city  state postalCode      country  \
# 0  Bronz Apt. 3/6 Tesvikiye          Singapore   None     079903    Singapore
# 1                      None            Kita-ku  Osaka   530-0003        Japan
# 2             1 Garden Road  Central Hong Kong   None       None    Hong Kong
# 3     NatWest Center #13-03        Makati City   None    1227 MM  Philippines
# 4                      None          Minato-ku  Tokyo   106-0032        Japan
#
#    salesRepEmployeeNumber  creditLimit
# 0                    1621     103800.0
# 1                    1621      81200.0
# 2                    1621      58600.0
# 3                    1621      81500.0
# 4                    1621      94400.0

# %%
result_dataFrame.to_csv('data/import_customers.csv')
